# %% [markdown]
# # 01 – Data Loading
#
# Load the sample dataset, inspect its shape, and verify all required columns are present.

# %%
import pandas as pd
import numpy as np

# Load the sample dataset
df = pd.read_csv('../data/sample/sample_posts.csv')
print(f'Shape: {df.shape}')
df.head()

# %%
# Check column names
print('Columns:', df.columns.tolist())

# %%
# Data types
df.dtypes

# %%
# Missing values
df.isnull().sum()

# %%
# Basic statistics
df.describe()
